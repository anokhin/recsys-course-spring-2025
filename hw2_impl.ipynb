# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tqdm

from pathlib import Path

rand = random.Random(199998)

# %%
N_DATA_ROWS = 50000000
POSITIVE_TH = 0.8
N_USERS = 10000
N_TRACKS = 50000

# %%
def process_file(file: str | Path):
    df = pd.read_json(file, lines=True).sort_values(by='user')

    for i in range(len(df)):
        if df.at[i, 'time'] < POSITIVE_TH:
            continue

        if i > 0 and df.at[i-1, 'user'] == df.at[i, 'user']:
            yield [df.at[i, 'user'], df.at[i-1, 'track'], df.at[i-1, 'time'], df.at[i, 'track'], df.at[i, 'time']]
        else:
            yield [df.at[i, 'user'], N_TRACKS, 0.0, df.at[i, 'track'], df.at[i, 'time']]

# %%
data = []
data_files = list(Path('data_9GB').glob('*.json'))

while len(data) < N_DATA_ROWS and len(data_files) > 0:
    file = rand.choice(data_files)
    data_files.remove(file)

    print(f'Processing file {file}...')
    for u, py, pt, y, t in process_file(file):
        data.append((u, py, pt, y, t))
    print(f'{len(data)} rows')
# Out:
# Processing file data_9GB/botify_recommender_10_3.json...
# 108113 rows
# Processing file data_9GB/botify_recommender_10_4.json...
# 215815 rows
# Processing file data_9GB/botify_recommender_3_data.json...
# 323790 rows
# Processing file data_9GB/botify_recommender_10_1.json...
# 432050 rows
# Processing file data_9GB/botify_recommender_2_1.json...
# 538074 rows
# Processing file data_9GB/botify_recommender_1_1.json...
# 645335 rows
# Processing file data_9GB/botify_recommender_3_7.json...
# 753480 rows
# Processing file data_9GB/botify_recommender_40_2.json...
# 857713 rows
# Processing file data_9GB/botify_recommender_4_3.json...
# 963114 rows
# Processing file data_9GB/botify_recommender_10_10.json...
# 1071299 rows
# Processing file data_9GB/als_gcf_data2.json...
# 1074662 rows
# Processing file data_9GB/botify_recommender_4_data.json...
# 1179978 rows
# Processing file data_9GB/botify_recommender_20_8.json...
# 1288815 rows
# Processing file data_9GB/botify_recommender_4_6.json...
# 1394354 rows
# Processing file data_9GB/botify_recommender_20_6.json...
# 1503349 rows
# Processing file data_9GB/botify_recommender_10_8.json...
# 1611154 rows
# Processing file data_9GB/botify_recommender_2_3.json...
# 1717061 rows
# Processing file data_9GB/botify_recommender_30_2.json...
# 1824484 rows
# Processing file data_9GB/botify_recommender_30_9.json...
# 1931767 rows
# Processing file data_9GB/botify_recommender_2_7.json...
# 2037333 rows
# Processing file data_9GB/botify_recommender_2_8.json...
# 2143063 rows
# Processing file data_9GB/botify_recommender_1_9.json...
# 2250750 rows
# Processing file data_9GB/another-data-8.json...
# 2273724 rows
# Processing file data_9GB/botify_recommender_40_10.json...
# 2376784 rows
# Processing file data_9GB/another-data-1.json...
# 2399930 rows
# Processing file data_9GB/another-data-5.json...
# 2422760 rows
# Processing file data_9GB/botify_recommender_20_1.json...
# 2530463 rows
# Processing file data_9GB/botify_recommender_40_3.json...
# 2634086 rows
# Processing file data_9GB/botify_recommender_4_2.json...
# 2739681 rows
# Processing file data_9GB/botify_recommender_3_3.json...
# 2848396 rows
# Processing file data_9GB/botify_recommender_10_data.json...
# 2902092 rows
# Processing file data_9GB/botify_recommender_30_7.json...
# 3008874 rows
# Processing file data_9GB/als_gcf_data4.json...
# 3015641 rows
# Processing file data_9GB/botify_recommender_2_6.json...
# 3121387 rows
# Processing file data_9GB/botify_recommender_10_6.json...
# 3229218 rows
# Processing file data_9GB/botify_recommender_1_4.json...
# 3337162 rows
# Processing file data_9GB/sticky_artist_data2.json...
# 3340072 rows
# Processing file data_9GB/botify_recommender_1_6.json...
# 3448613 rows
# Processing file data_9GB/botify_recommender_40_9.json...
# 3551252 rows
# Processing file data_9GB/botify_recommender_30_1.json...
# 3658830 rows
# Processing file data_9GB/another-data-3.json...
# 3681821 rows
# Processing file data_9GB/botify_recommender_1_7.json...
# 3789106 rows
# Processing file data_9GB/toppop_data1.json...
# 3790571 rows
# Processing file data_9GB/botify_recommender_4_1.json...
# 3896311 rows
# Processing file data_9GB/botify_recommender_20_2.json...
# 4005137 rows
# Processing file data_9GB/botify_recommender_10_7.json...
# 4112075 rows
# Processing file data_9GB/botify_recommender_4_10.json...
# 4217576 rows
# Processing file data_9GB/botify_recommender_2_9.json...
# 4322990 rows
# Processing file data_9GB/botify_recommender_1_10.json...
# 4430869 rows
# Processing file data_9GB/botify_recommender_20_3.json...
# 4539390 rows
# Processing file data_9GB/botify_recommender_1_8.json...
# 4647314 rows
# Processing file data_9GB/botify_recommender_4_5.json...
# 4752663 rows
# Processing file data_9GB/botify_recommender_40_1.json...
# 4856824 rows
# Processing file data_9GB/botify_recommender_1_5.json...
# 4964710 rows
# Processing file data_9GB/botify_recommender_20_7.json...
# 5074155 rows
# Processing file data_9GB/botify_recommender_40_7.json...
# 5178040 rows
# Processing file data_9GB/als_gcf_data3.json...
# 5185045 rows
# Processing file data_9GB/botify_recommender_30_5.json...
# 5292393 rows
# Processing file data_9GB/botify_recommender_4_9.json...
# 5398219 rows
# Processing file data_9GB/botify_recommender_4_4.json...
# 5503716 rows
# Processing file data_9GB/botify_recommender_2_data.json...
# 5609870 rows
# Processing file data_9GB/another-data-6.json...
# 5632988 rows
# Processing file data_9GB/botify_recommender_10_2.json...
# 5740790 rows
# Processing file data_9GB/botify_recommender_2_4.json...
# 5847134 rows
# Processing file data_9GB/botify_recommender_3_8.json...
# 5955636 rows
# Processing file data_9GB/botify_recommender_3_6.json...
# 6063859 rows
# Processing file data_9GB/botify_recommender_40_data.json...
# 6115625 rows
# Processing file data_9GB/botify_recommender_20_10.json...
# 6224042 rows
# Processing file data_9GB/dssm_lfm_data_1.json...
# 6248689 rows
# Processing file data_9GB/botify_recommender_1_data.json...
# 6356285 rows
# Processing file data_9GB/botify_recommender_20_data.json...
# 6409528 rows
# Processing file data_9GB/als_gcf_data1.json...
# 6412992 rows
# Processing file data_9GB/dssm_lfm_data_2.json...
# 6437492 rows
# Processing file data_9GB/botify_recommender_40_6.json...
# 6541306 rows
# Processing file data_9GB/botify_recommender_40_8.json...
# 6645022 rows
# Processing file data_9GB/botify_recommender_3_9.json...
# 6752995 rows
# Processing file data_9GB/another-data-7.json...
# 6775808 rows
# Processing file data_9GB/botify_recommender_1_2.json...
# 6883183 rows
# Processing file data_9GB/another-data-10.json...
# 6906215 rows
# Processing file data_9GB/botify_recommender_20_9.json...
# 7017057 rows
# Processing file data_9GB/botify_recommender_3_10.json...
# 7125639 rows
# Processing file data_9GB/botify_recommender_1_3.json...
# 7233394 rows
# Processing file data_9GB/botify_recommender_30_4.json...
# 7341270 rows
# Processing file data_9GB/botify_recommender_4_8.json...
# 7447546 rows
# Processing file data_9GB/botify_recommender_30_3.json...
# 7555009 rows
# Processing file data_9GB/botify_recommender_40_4.json...
# 7658988 rows
# Processing file data_9GB/botify_recommender_30_6.json...
# 7765964 rows
# Processing file data_9GB/botify_recommender_2_5.json...
# 7872095 rows
# Processing file data_9GB/botify_recommender_10_9.json...
# 7979024 rows
# Processing file data_9GB/botify_recommender_3_4.json...
# 8087233 rows
# Processing file data_9GB/botify_recommender_3_1.json...
# 8195878 rows
# Processing file data_9GB/botify_recommender_2_2.json...
# 8301248 rows
# Processing file data_9GB/another-data-9.json...
# 8324202 rows
# Processing file data_9GB/botify_recommender_40_5.json...
# 8428941 rows
# Processing file data_9GB/another-data-4.json...
# 8451899 rows
# Processing file data_9GB/botify_recommender_30_data.json...
# 8505248 rows
# Processing file data_9GB/botify_recommender_30_8.json...
# 8611852 rows
# Processing file data_9GB/botify_recommender_3_2.json...
# 8720656 rows
# Processing file data_9GB/botify_recommender_3_5.json...
# 8829170 rows
# Processing file data_9GB/botify_recommender_20_5.json...
# 8936727 rows
# Processing file data_9GB/botify_recommender_4_7.json...
# 9042376 rows
# Processing file data_9GB/botify_recommender_2_10.json...
# 9148008 rows
# Processing file data_9GB/sticky_artist_data1.json...
# 9150989 rows
# Processing file data_9GB/toppop_data2.json...
# 9152457 rows
# Processing file data_9GB/botify_recommender_10_5.json...
# 9260396 rows
# Processing file data_9GB/botify_recommender_20_4.json...
# 9368387 rows
# Processing file data_9GB/botify_recommender_30_10.json...
# 9476099 rows
# Processing file data_9GB/another-data-2.json...
# 9499039 rows

# %%
data_by_user = {}

for u, py, pt, y, t in data:
    if u not in data_by_user:
        data_by_user[u] = set()
    data_by_user[u].add(y)

for u in data_by_user.keys():
    data_by_user[u] = list(data_by_user[u])

# %%
with open('recommendations_kiss.json', 'w') as file:
    for u in sorted(list(data_by_user.keys())):
        file.write(f'{{"user":{u},"tracks":[{",".join(map(str, data_by_user[u]))}]}}\n')
